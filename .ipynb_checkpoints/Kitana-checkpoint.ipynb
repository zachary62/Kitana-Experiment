# %%
from datamarket import *
import autosklearn.classification
import autosklearn.metrics
import time

# %% [markdown]
# # Read the data and train model without augmentation
# We first use factorized linear regression, then automl.

# %%
# read buyer dataset
buyer = pd.read_csv("gender.csv")

# train test split
msk = split_mask(len(buyer)) < 0.8
buyer_train = buyer[msk].copy()
buyer_test = buyer[~msk].copy()

# %%
buyer_train_data = agg_dataset()
buyer_train_data.load(buyer_train, ["Number Tested", "Mean Scale Score"], ["DBN", ["DBN","Grade"], "Year", "Category"], "buyer")
buyer_train_data.process_target("Mean Scale Score")
buyer_train_data.to_numeric_and_impute_all()
buyer_train_data.remove_redundant_columns()
buyer_train_data.create_count_true()
buyer_train_data.compute_agg()

buyer_test_data = agg_dataset()
buyer_test_data.load(buyer_test, ["Number Tested", "Mean Scale Score"], ["DBN", ["DBN","Grade"], "Year", "Category"], "buyer")
buyer_test_data.process_target("Mean Scale Score")
buyer_test_data.to_numeric_and_impute_all()
buyer_test_data.remove_redundant_columns()
buyer_test_data.create_count_true()
buyer_test_data.compute_agg()

# %%
# model performance before augmentation with linear regression
train_cov = buyer_train_data.covariance
test_cov = buyer_test_data.covariance
X = ['Number Tested']
y = 'Mean Scale Score'

parameter = linear_regression(train_cov, ["buyer:" + x for x in X], "buyer:" + y)
print("R2 score is:" + str(r2(test_cov, ["buyer:" + x for x in X], "buyer:" + y, parameter)))
# Out:
# R2 score is:0.00870173150760123

# %%
time_budget = 300

# %%
# preprocess data
categories = ['Year', "Grade", "Category"]
for cate in categories:
    buyer = buyer.astype({cate: 'category'})

buyer[y] = pd.to_numeric(buyer[y], errors='coerce')
buyer.dropna(subset=[y],inplace=True)
msk = split_mask(len(buyer)) < 0.8
buyer_train = buyer[msk].copy()
buyer_test = buyer[~msk].copy()

# model performance with autoML 
X_train = buyer_train[X + categories]
y_train = buyer_train[y]
X_test = buyer_test[X + categories]
y_test = buyer_test[y]

automl = autosklearn.regression.AutoSklearnRegressor(
# automl = autosklearn.classification.AutoSklearnClassifier(
    time_left_for_this_task=time_budget,
    per_run_time_limit=int(time_budget/3),
    memory_limit=6072
#     metric=autosklearn.metrics.r2
)
automl.fit(X_train, y_train, X_test, y_test, dataset_name='buyer')

now_n = datetime.now()
current_time = now_n.strftime("%H:%M:%S")
print("Current Time =", current_time)
# Out:
# [WARNING] [2022-04-15 23:19:36,255:Client-EnsembleBuilder] No models better than random - using Dummy loss!Number of models besides current dummy model: 1. Number of dummy models: 1
# [WARNING] [2022-04-15 23:19:55,650:Client-EnsembleBuilder] No models better than random - using Dummy loss!Number of models besides current dummy model: 2. Number of dummy models: 1
# Current Time = 23:24:04

# %%
poT = automl.performance_over_time_
poT.plot(
    x='Timestamp',
    kind='line',
    legend=True,
    title='Auto-sklearn accuracy over time',
    grid=True,
)
# Out:
# <AxesSubplot:title={'center':'Auto-sklearn accuracy over time'}, xlabel='Timestamp'>

# %% [markdown]
# # Load seller datasets and build market

# %%
import json
with open('market_data.json', 'r') as openfile:
    market_data = json.load(openfile)
    
sellers = []

for data in market_data:
    file, dimension, name = data
    df = pd.read_csv(file)
    aggdata = agg_dataset()
    aggdata.load(df, [], dimension, name)
    aggdata.find_features()
    aggdata.remove_redundant_columns()
    aggdata.compute_agg(True)
    aggdata.create_count_true()
    sellers.append((aggdata, dimension[0]))
# Out:
# /home/jupyter/arda/arda-datasets/kitana/datamarket.py:202: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.data['cov:Q:' + tablename + ":" + attributes[i] + ","+ tablename + ":" + attributes[j]] = self.data[attributes[i]] * self.data[attributes[j]]

# %%
buyer
# Out:
#           DBN                                    School Name       Grade  \
# 0      01M015                        PS 015 ROBERTO CLEMENTE           3
# 1      01M015                        PS 015 ROBERTO CLEMENTE           3
# 4      01M015                        PS 015 ROBERTO CLEMENTE           3
# 5      01M015                        PS 015 ROBERTO CLEMENTE           3
# 8      01M015                        PS 015 ROBERTO CLEMENTE           3
# ...       ...                                            ...         ...
# 47730  32K562  EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION  All Grades
# 47731  32K562  EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION  All Grades
# 47732  32K562  EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION  All Grades
# 47733  32K562  EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION  All Grades
# 47734  32K562  EVERGREEN MIDDLE SCHOOL FOR URBAN EXPLORATION  All Grades
#
#        Year Category  Number Tested  Mean Scale Score Level1_N Level1_%  \
# 0      2013   Female             12             285.0        7     58.3
# 1      2013     Male             15             292.0        7     46.7
# 4      2015   Female              7             289.0        3     42.9
# 5      2015     Male              9             276.0        6     66.7
# 8      2017   Female             13             308.0        4     30.8
# ...     ...      ...            ...               ...      ...      ...
# 47730  2015     Male            161             274.0       98     60.9
# 47731  2016   Female            125             286.0       48     38.4
# 47732  2016     Male            141             282.0       62     44.0
# 47733  2017   Female            138             289.0       49     35.5
# 47734  2017     Male            144             284.0       55     38.2
#
#       Level2_N Level2_% Level3_N Level3_% Level4_N Level4_% Level3+4_N  \
# 0            5     41.7        0      0.0        0      0.0          0
# 1            6     40.0        2     13.3        0      0.0          2
# 4            3     42.9        1     14.3        0      0.0          1
# 5            2     22.2        1     11.1        0      0.0          1
# 8            4     30.8        3     23.1        2     15.4          5
# ...        ...      ...      ...      ...      ...      ...        ...
# 47730       52     32.3       11      6.8        0      0.0         11
# 47731       63     50.4       12      9.6        2      1.6         14
# 47732       70     49.6        9      6.4        0      0.0          9
# 47733       70     50.7       14     10.1        5      3.6         19
# 47734       79     54.9        9      6.3        1      0.7         10
#
#       Level3+4_%
# 0            0.0
# 1           13.3
# 4           14.3
# 5           11.1
# 8           38.5
# ...          ...
# 47730        6.8
# 47731       11.2
# 47732        6.4
# 47733       13.8
# 47734        6.9
#
# [47270 rows x 17 columns]

# %%
start = time.time()

m = 1
# budget = 140000
for i in range(m):
    best_seller = None
    best_seller_attrs = []
    best_dimension = None
    best_r2 = 0

    for sellerdata, dimension in sellers:
        print(sellerdata.name)
#         pd.merge(buyer_train_data.data, sellerdata.data, left_on=dimension, right_on=dimension)
        # check if current seller has been bought
        if sellerdata.name in buyer_train_data.datasets:
            continue
            
#         count_true_join = connect_count(buyer_train_data, sellerdata, dimension)
#         if count_true_join["cov:c"].sum() > budget:
#             print("beyond budget!!")
#             continue
        

        # find the attributes and r2 of augmenting
        cur_atts, final_r2 = select_features(buyer_train_data, buyer_test_data, sellerdata, dimension,6, y)
        print(cur_atts, final_r2)
        if final_r2 > best_r2:
            best_seller = sellerdata
            best_dimension = dimension
            best_seller_attrs = cur_atts
            best_r2 = final_r2

    print(best_seller.name, best_seller_attrs, best_r2)
    
#     if len([x for x in best_seller_attrs if x in best_seller.X]) == 0:
#         buyer_train_data.datasets.add(best_seller)
#         buyer_test_data.datasets.add(best_seller)
#     else:
#         buyer_train_data.absorb(best_seller, best_dimension, best_seller_attrs + [buyer_train_data.name + ":" + y])
#         buyer_test_data.absorb(best_seller, best_dimension, best_seller_attrs + [buyer_train_data.name + ":" + y])

end = time.time()
# Out:
# disc
# ['disc:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested', 'disc:SY1617 TOTAL REMOVALS/SUSPENSIONS'] 0.01809409651495142
# esl
# ['esl:Level 3+4 %', 'esl:Level 3 %', 'esl:Mean Scale Score', 'esl:Level 4 #', 'esl:Grade', 'esl:Level 2 #'] 0.4357000026310125
# math
# ['math:Level 4 %', 'math:Level 1 %', 'math:Grade', 'math:Year', 'math:Mean Scale Score', 'math:Level 4 #'] 0.4008744384393087
# oss
# ['oss:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# pe
# ['pe:Student Enrollment', 'pe:Full Time Licensed PE Teachers', 'pe:Total Part Time and Full Time PE Teachers*', 'buyer:Number Tested', 'pe:Geographical District', 'pe:Admin District'] 0.10373135904818298
# s2tr
# ['s2tr:School Pupil-Teacher Ratio', 'buyer:Number Tested'] 0.21007728228589773
# sat
# ['buyer:Number Tested', 'sat:Writing Mean', 'sat:Number of Test Takers', 'sat:Mathematics Mean', 'sat:Critical Reading Mean'] 0.010881058613883776
# pro
# ['pro:2012-2013 PERFORMANCE CATEGORY SCORE', 'pro:2012-2013 ADDITIONAL CREDIT', 'pro:DISTRICT', 'pro:2012-2013 PROGRESS CATEGORY SCORE', 'pro:2012-13 OVERALL PERCENTILE', 'pro:2012-2013 ENVIRONMENT CATEGORY SCORE'] 0.3844428591985023
# transfer
# ['buyer:Number Tested', 'transfer:% Self-Contained', 'transfer:Overall Score', 'transfer:Average Math Proficiency'] 0.008701731507611221
# yabc
# ['buyer:Number Tested', 'yabc:Overall Rank', 'yabc:Average Math Proficiency', 'yabc:% ELL', 'yabc:Average English Proficiency', 'yabc:% Self-Contained'] 0.008701731507683164
# dm1
# ['dm1:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested', 'dm1:SY1617 TOTAL REMOVALS/SUSPENSIONS'] 0.01809409651495142
# dm2
# ['dm2:MATH %Level 1', 'dm2:#Hispanic', 'dm2:MATH %Level 2', 'dm2:%Hispanic', 'dm2:Total Enrollment', 'dm2:#Male'] 0.29561354244898996
# dm3
# ['dm3:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm4
# ['dm4:Math #Level 1', 'dm4:ELA #Test Takers', 'buyer:Number Tested', 'dm4:#Hispanic', 'dm4:#Female', 'dm4:Total Enrollment'] 0.11555183035105887
# dm5
# ['buyer:Number Tested', 'dm5:Pct Level 4', 'dm5:Num Level 3', 'dm5:Mean Scale Score'] 0.008701731507647192
# dm6
# ['dm6:Register', 'dm6:# Schools', 'dm6:ID', 'buyer:Number Tested', 'dm6:Geographical District Code'] 0.09282359142148977
# dm7
# ['dm7:Economic Need Index', 'dm7:% Asian', 'dm7:% Poverty', 'dm7:% Students with Disabilities', 'dm7:% English Language Learners', 'dm7:% Black'] 0.5562472589673916
# dm8
# ['dm8:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested', 'dm8:SY1617 TOTAL REMOVALS/SUSPENSIONS'] 0.01809409651495142
# dm9
# ['dm9:Average Class Size', 'dm9:Grade Level', 'dm9:Number of Students', 'dm9:Minimum Class Size', 'buyer:Number Tested', 'dm9:Number of Classes'] 0.06703750307833745
# dm10
# ['buyer:Number Tested', 'dm10:% of cohort 2', 'dm10:Advanced Regents #', 'dm10:% of cohort 1', 'dm10:% of grads 3', 'dm10:% of cohort'] 0.01111730373446862
# dm11
# ['dm11:2009-2010 PERFORMANCE CATEGORY SCORE', 'dm11:2009-2010 PROGRESS CATEGORY SCORE', 'dm11:DISTRICT', 'dm11:PEER INDEX*', 'dm11:2009-2010 ENVIRONMENT CATEGORY SCORE', 'buyer:Number Tested'] 0.23584175299057275
# dm12
# ['dm12:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm13
# ['dm13:% Poverty', 'dm13:% Asian', 'buyer:Number Tested', 'dm13:% Ell', 'dm13:Grades 6-8 Enrollment', 'dm13:District'] 0.1612439466005765
# dm14
# ['buyer:Number Tested', 'dm14:Total SW & GC'] 0.016175429672349972
# dm15
# ['dm15:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm16
# ['buyer:Number Tested', 'dm16:Total Parent \nResponse Rate', 'dm16:Total Teacher Response Rate', 'dm16:Total Student Response Rate'] 0.01614369381955627
# dm17
# ['buyer:Number Tested'] 0.00870173150757525
# dm18
# ['dm18:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested', 'dm18:SY1617 TOTAL REMOVALS/SUSPENSIONS'] 0.01809409651495142
# dm19
# ['buyer:Number Tested', 'dm19:#Hispanic', 'dm19:#Female', 'dm19:Total Enrollment', 'dm19:#Male', 'dm19:#Black'] 0.008824748513604597
# dm20
# ['dm20:Percent Satisfaction: School Culture', 'dm20:Percent Satisfaction:Systems for Improvement', 'buyer:Number Tested', 'dm20:Percent Satisfaction:Instructional Core', 'dm20:Total Teacher Response Rate'] 0.2176733042372998
# dm21
# ['dm21:Ratio GC & SW', 'dm21:Full Time', 'dm21:Total GC', 'dm21:SY2014-15 Enrollment', 'dm21:Total SW & GC', 'dm21:Ratio GC Only'] 0.15685544141835683
# dm22
# ['dm22:% Eligible for Free or Reduced Lunches', 'dm22:% Asian', 'dm22:% Students with Disabilities', 'dm22:% English Language Learners', 'dm22:% Black', 'dm22:% Hispanic'] 0.5976880463376915
# dm23
# ['dm23:Total Parent \nResponse Rate', 'buyer:Number Tested'] 0.025666417574606193
# dm24
# ['buyer:Number Tested', 'dm24:Collaborative Teachers - Percent Positive', 'dm24:Strong Family-Community Ties - Percent Positive'] 0.008701731507647192
# dm25
# ['buyer:Number Tested', 'dm25:Total Cohort Num', 'dm25:Total Grads Num'] 0.008779883167848945
# dm26
# ['buyer:Number Tested'] 0.00870173150757525
# dm27
# ['buyer:Number Tested', 'dm27:Total Cohort Num', 'dm27:Total Grads Num'] 0.008740137733113773
# dm28
# ['dm28:Ratio GC & SW', 'dm28:Full-Time', 'dm28:Total GC & SW', 'dm28:2014 Enrollment\nPK-12', 'dm28:Ratio GC Only', 'dm28:Total GC'] 0.16190285644471392
# dm29
# ['buyer:Number Tested', 'dm29:Total Enrolled Students'] 0.008714190815075074
# dm30
# ['dm30:Rigorous Instruction Score', 'dm30:Trust Score', 'dm30:Strong Family-Community Ties Score', 'buyer:Number Tested', 'dm30:Collaborative Teachers Score', 'dm30:Effective School Leadership Score'] 0.1999378692170708
# dm31
# ['dm31:Mbps Bandwidth', 'buyer:Number Tested'] 0.025663300506275077
# dm32
# ['dm32:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm33
# ['buyer:Number Tested', 'dm33:Total Cohort Num', 'dm33:Cohort Year'] 0.008751311479171742
# dm34
# ['dm34:2012-2013 PERFORMANCE CATEGORY SCORE', 'dm34:2012-2013 ADDITIONAL CREDIT', 'dm34:DISTRICT', 'dm34:2012-2013 PROGRESS CATEGORY SCORE', 'dm34:2012-13 OVERALL PERCENTILE', 'dm34:2012-2013 ENVIRONMENT CATEGORY SCORE'] 0.3844527643832294
# dm35
# ['buyer:Number Tested', 'dm35:Percent White', 'dm35:Supportive Environment - Percent Positive', 'dm35:Economic Need Index', 'dm35:Collaborative Teachers - Percent Positive', 'dm35:Effective School Leadership - Percent Positive'] 0.008701731507683164
# dm36
# ['buyer:Number Tested', 'dm36:Total Enrollment (Half Day & Full Day)', 'dm36:#Female', 'dm36:#Male'] 0.01032114899883374
# dm37
# ['buyer:Number Tested', 'dm37:# of students in grades 9-12', 'dm37:City Council District', 'dm37:Community School District', 'dm37:# of students in grades 9-12 who have completed at least one semester of health instruction', 'dm37:# of 15-16 June and August graduates meeting high school health requirements'] 0.009032703424743382
# dm38
# ['buyer:Number Tested', 'dm38:Latitude', 'dm38:Council District', 'dm38:BIN', 'dm38:Census Tract', 'dm38:number_programs'] 0.010341908080928386
# dm39
# ['dm39:Level 3+4: %', 'dm39:Level 4: %', 'dm39:Level 1: #', 'buyer:Number Tested', 'dm39:Grade', 'dm39:Level 3: #'] 0.2860172084675675
# dm40
# ['dm40:Mean Scale Score', 'dm40:Number Tested', 'dm40:Level2_N', 'dm40:Level1_N', 'dm40:Level3+4_N', 'dm40:Grade'] 0.4029829196163125
# dm41
# ['dm41:Level3+4_%', 'dm41:Level1_N', 'dm41:Mean Scale Score', 'buyer:Number Tested', 'dm41:Level4_%', 'dm41:Number Tested'] 0.33967617686368756
# dm42
# ['dm42:Ratio GC & SW', 'dm42:Full-Time', 'dm42:Total GC & SW', 'dm42:2014 Enrollment\nPK-12', 'dm42:Ratio GC Only', 'dm42:Total GC'] 0.16190285644471392
# dm43
# ['buyer:Number Tested'] 0.00870173150757525
# dm44
# ['dm44:Present', 'dm44:Tot', 'dm44:GradeSort', 'dm44:MonthCode', 'dm44:Released', 'dm44:RosterCount'] 0.13670289369702227
# dm45
# ['dm45:Student Enrollment', 'dm45:Full Time Licensed PE Teachers', 'dm45:Total Part Time and Full Time PE Teachers*', 'buyer:Number Tested', 'dm45:Geographical District', 'dm45:Admin District'] 0.10373135904818298
# dm46
# ['dm46:MATH %Level 1', 'dm46:#Hispanic', 'dm46:MATH %Level 2', 'dm46:%Hispanic', 'dm46:Total Enrollment', 'dm46:#Male'] 0.29561354244898996
# dm47
# ['buyer:Number Tested', 'dm47:Regents without Advanced#', 'dm47:Total Grads #', 'dm47:Advanced Regents#', 'dm47:Still Enrolled% of cohort'] 0.008701731507647192
# dm48
# ['dm48:Total Parent \nResponse Rate', 'buyer:Number Tested'] 0.04573431361772429
# dm49
# ['dm49:Math #Level 1', 'dm49:ELA #Test Takers', 'buyer:Number Tested', 'dm49:ELA #Level 2', 'dm49:#Hispanic', 'dm49:#Female'] 0.09961455488203408
# dm50
# ['dm50:Average Class Size', 'dm50:Grade Level', 'dm50:Number of Students', 'dm50:Minimum Class Size', 'buyer:Number Tested', 'dm50:Number of Classes'] 0.06528488657079434
# dm51
# ['buyer:Number Tested'] 0.00870173150757525
# dm52
# ['dm52:% Students in Temporary Housing', 'dm52:# Doubled Up', 'dm52:# Students in Temporary Housing', 'dm52:# Students Residing in Shelter', 'dm52:# Total Students', 'buyer:Number Tested'] 0.31945636671252764
# dm53
# ['dm53:# White', 'dm53:# Asian', 'dm53:# Students with Disabilities', 'dm53:# Other', 'dm53:# English Language Learners', 'dm53:# Female'] 0.43324483035804295
# dm54
# ['dm54:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm55
# ['dm55:Count of Testers', 'dm55:Count of Students in HS Admissions', 'buyer:Number Tested'] 0.0518551432426837
# dm56
# ['buyer:Number Tested'] 0.00870173150757525
# dm57
# ['buyer:Number Tested'] 0.00870173150757525
# dm58
# ['dm58:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm59
# ['dm59:Average Grade 4 English Proficiency', 'dm59:Economic Need Index', 'dm59:Average Grade 4 Math Proficiency', 'dm59:% ELL', 'dm59:% Self-Contained', 'buyer:Number Tested'] 0.6643513790215417
# dm60
# ['buyer:Number Tested', 'dm60:% of cohort 2', 'dm60:Advanced Regents #', 'dm60:% of cohort 1', 'dm60:% of grads 1', 'dm60:Cohort #'] 0.011183742717524758
# dm61
# ['dm61:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested', 'dm61:SY1617 TOTAL REMOVALS/SUSPENSIONS'] 0.01809297983843161
# dm62
# ['dm62:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm63
# ['dm63:Percent HRA Eligible', 'dm63:Student Attendance Rate', 'dm63:Percent English Language Learners', 'dm63:Percent Black', 'dm63:Percent Hispanic', 'dm63:Percent Students with Disabilities'] 0.5909455795371976
# dm64
# ['dm64:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested', 'dm64:SY1617 TOTAL REMOVALS/SUSPENSIONS'] 0.01809409651495142
# dm65
# ['dm65:Mean Scale Score', 'dm65:Number Tested', 'dm65:Level2_N', 'dm65:Level1_N', 'dm65:Level3+4_N', 'dm65:Level3+4_%'] 0.4256242059789406
# dm66
# ['dm66:Community School District', 'dm66:City Council District', 'buyer:Number Tested'] 0.023554935025373536
# dm67
# ['buyer:Number Tested'] 0.00870173150757525
# dm68
# ['buyer:Number Tested', 'dm68:Total Enrollment (Half Day & Full Day)', 'dm68:#Female', 'dm68:#Male'] 0.01001748442135153
# dm69
# ['buyer:Number Tested', 'dm69:Total Cohort Num', 'dm69:Cohort Year'] 0.008724461066355937
# dm70
# ['dm70:School Pupil-Teacher Ratio', 'buyer:Number Tested'] 0.2422269047412472
# dm71
# ['buyer:Number Tested', 'dm71:Total Enrolled Students'] 0.010614070980117019
# dm72
# ['dm72:Pct Level 4', 'dm72:Pct Level 1', 'dm72:Mean Scale Score', 'dm72:Year', 'dm72:Grade', 'dm72:Num Level 4'] 0.40064909411371474
# dm73
# ['dm73:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm74
# ['buyer:Number Tested', 'dm74:Total Enrolled Students'] 0.008730500304642175
# dm75
# ['buyer:Number Tested', 'dm75:% Free Lunch', 'dm75:Percent Other', 'dm75:Years of Principal Experience at This School', 'dm75:Enrollment', 'dm75:Percent Asian'] 0.01484923463469734
# dm76
# ['dm76:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm77
# ['dm77:Community School District', 'dm77:City Council District', 'buyer:Number Tested'] 0.023554935025373536
# dm78
# ['buyer:Number Tested'] 0.00870173150757525
# dm79
# ['buyer:Number Tested', 'dm79:Total Enrollment (Half Day & Full Day)', 'dm79:#Female', 'dm79:#Male'] 0.01001748442135153
# dm80
# ['buyer:Number Tested', 'dm80:Total Cohort Num', 'dm80:Cohort Year'] 0.008724461066355937
# dm81
# ['dm81:School Pupil-Teacher Ratio', 'buyer:Number Tested'] 0.2422269047412472
# dm82
# ['buyer:Number Tested', 'dm82:Total Enrolled Students'] 0.010614070980117019
# dm83
# ['dm83:Pct Level 4', 'dm83:Pct Level 1', 'dm83:Mean Scale Score', 'dm83:Year', 'dm83:Grade', 'dm83:Num Level 4'] 0.40064909411371474
# dm84
# ['dm84:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm85
# ['buyer:Number Tested', 'dm85:Total Enrolled Students'] 0.008730500304642175
# dm86
# ['buyer:Number Tested', 'dm86:% Free Lunch', 'dm86:Percent Other', 'dm86:Years of Principal Experience at This School', 'dm86:Enrollment', 'dm86:Percent Asian'] 0.01484923463469734
# dm87
# ['dm87:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm88
# ['dm88:Percent Scoring 80 or Above', 'buyer:Number Tested', 'dm88:Total Tested', 'dm88:Number Scoring 65 or Above', 'dm88:Mean Score', 'dm88:Number Scoring Below 65'] 0.061803130707185794
# dm89
# ['dm89:Q9_R2_C1', 'dm89:Q9_R5_C1', 'dm89:Q7_2', 'dm89:Q7_4', 'dm89:Q9_R3_C1', 'buyer:Number Tested'] 0.03973417915681965
# dm89
# ['dm89:Q9_R2_C1', 'dm89:Q9_R5_C1', 'dm89:Q7_2', 'dm89:Q7_4', 'dm89:Q9_R3_C1', 'buyer:Number Tested'] 0.03973417915681965
# dm90
# ['buyer:Number Tested', 'dm90:app_gr09', 'dm90:seat_gr09'] 0.008782219306006644
# dm91
# ['buyer:Number Tested', 'dm91:%Female', 'dm91:Total Pre-K Enrollment (Half Day & Full Day)', 'dm91:#Male', 'dm91:#Female'] 0.010277958965838052
# dm92
# ['dm92:Level 3+4 %', 'dm92:Level 4 %', 'dm92:Mean Scale Score', 'dm92:Level 4 #', 'dm92:Grade', 'dm92:Number Tested'] 0.3912741488065117
# dm93
# ['buyer:Number Tested'] 0.00870173150757525
# dm94
# ['buyer:Number Tested'] 0.00870173150757525
# dm95
# ['dm95:Percent HRA Eligible', 'dm95:Student Attendance Rate', 'dm95:Supportive Environment - Percent Positive', 'dm95:Percent English Language Learners', 'dm95:Percent Black', 'dm95:Percent Students with Disabilities'] 0.6170000984956303
# dm96
# ['dm96:Percent Scoring 80 or Above', 'buyer:Number Tested', 'dm96:Percent Scoring 65 or Above', 'dm96:Total Tested', 'dm96:Number Scoring 65 or Above', 'dm96:Number Scoring Below 65'] 0.062243146138934
# dm97
# ['buyer:Number Tested', 'dm97:Post-secondary Enrollment Rate (6 months)', 'dm97:% Passing', 'dm97:2 year or 4 year College (6 months)', 'dm97:% Passing 2', 'dm97:Average Score SAT Writing'] 0.008701731507647192
# dm98
# ['dm98:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm99
# ['dm99:ADDITIONAL CREDIT', 'dm99:OVERALL SCORE', 'dm99:PEER INDEX*', 'dm99:DISTRICT', 'buyer:Number Tested', 'dm99:ENVIRONMENT CATEGORY SCORE'] 0.1745295586860739
# dm100
# ['dm100:Average Class Size', 'dm100:Grade Level', 'dm100:Number of Students', 'dm100:Minimum Class Size', 'buyer:Number Tested', 'dm100:Number of Classes'] 0.06528488657079434
# dm101
# ['buyer:Number Tested', 'dm101:Local Num', 'dm101:Cohort Year', 'dm101:Still Enrolled Num', 'dm101:Total Regents Num'] 0.008843321485494049
# dm102
# ['buyer:Number Tested', 'dm102:Community Board', 'dm102:Council District ', 'dm102:Latitude', 'dm102:BIN', 'dm102:Census Tract'] 0.009761607362563485
# dm103
# ['buyer:Number Tested', 'dm103:Total Tested'] 0.01018700604744005
# dm104
# ['buyer:Number Tested', 'dm104:% Self-Contained', 'dm104:Overall Score', 'dm104:Average Math Proficiency'] 0.008701731507611221
# dm105
# ['dm105:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm106
# ['buyer:Number Tested', 'dm106:Supportive Environment - Percent Positive', 'dm106:Strong Family-Community Ties - Percent Positive', 'dm106:Trust - Percent Positive'] 0.008701731507683164
# dm107
# ['dm107:2012-2013 PERFORMANCE CATEGORY SCORE', 'dm107:2012-2013 ADDITIONAL CREDIT', 'dm107:DISTRICT', 'dm107:2012-2013 PROGRESS CATEGORY SCORE', 'dm107:2012-13 OVERALL PERCENTILE', 'dm107:2012-2013 ENVIRONMENT CATEGORY SCORE'] 0.3844428591985023
# dm108
# ['dm108:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested', 'dm108:SY1617 TOTAL REMOVALS/SUSPENSIONS'] 0.01809409651495142
# dm109
# ['buyer:Number Tested', 'dm109:Total SW'] 0.01665715939668544
# dm110
# ['buyer:Number Tested', 'dm110:Year', 'dm110:Num Level 1', 'dm110:Pct Level 1', 'dm110:Num Level 3'] 0.008701731507719024
# dm111
# ['buyer:Number Tested'] 0.00870173150757525
# dm112
# ['buyer:Number Tested'] 0.00870173150757525
# dm113
# ['buyer:Number Tested', 'dm113:Total Enrolled Students'] 0.008761916069247033
# dm114
# ['dm114:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm115
# ['dm115:PERFORMANCE CATEGORY SCORE', 'dm115:PEER INDEX*', 'dm115:ADDITIONAL CREDIT', 'dm115:DISTRICT', 'dm115:ENVIRONMENT CATEGORY SCORE', 'buyer:Number Tested'] 0.17323059971448318
# dm116
# ['buyer:Number Tested', 'dm116:Average English Proficiency', 'dm116:% Black or Hispanic', 'dm116:Enrollment', 'dm116:% Students with Disabilities', 'dm116:Average Math Proficiency'] 0.012202088661794064
# dm117
# ['buyer:Number Tested', 'dm117:# achieving APM', 'dm117:# APM Cohort', 'dm117:Cohort Year', 'dm117:# number of graduates'] 0.00887137168283203
# dm118
# ['buyer:Number Tested', 'dm118:Average Change Attendance', 'dm118:Peer 100% of Range 13', 'dm118:Peer 100% of Range', 'dm118:Peer Percent of Range', 'dm118:Peer 100% of Range 4'] 0.008701731507719024
# dm119
# ['dm119:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested', 'dm119:SY1617 TOTAL REMOVALS/SUSPENSIONS'] 0.01809409651495142
# dm120
# ['dm120:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm121
# ['dm121:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm122
# ['buyer:Number Tested'] 0.00870173150757525
# dm123
# ['buyer:Number Tested'] 0.00870173150757525
# dm124
# ['buyer:Number Tested', 'dm124:Grade level'] 0.015702184324781654
# dm125
# ['dm125:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm126
# ['buyer:Number Tested', 'dm126:Economic Need Index', 'dm126:Enrollment', 'dm126:Average Grade 8 Math Proficiency', 'dm126:Percent Overage/ Undercredited', 'dm126:Percent Black'] 0.015039718261236734
# dm127
# ['dm127:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm128
# ['buyer:Number Tested', 'dm128:Economic Need Index', 'dm128:Enrollment', 'dm128:Average Grade 8 Math Proficiency', 'dm128:Percent Overage/ Undercredited', 'dm128:Percent Black'] 0.015039718261236734
# dm129
# ['dm129:# of teachers assigned to teach health', 'dm129:Community School District', 'dm129:City Council District', 'buyer:Number Tested'] 0.0388391331002228
# dm130
# ['dm130:Average Class Size', 'buyer:Number Tested', 'dm130:Number of Classes', 'dm130:Number of Students'] 0.025873275872708823
# dm131
# ['dm131:Level 4 %', 'dm131:Level 3+4 %', 'buyer:Number Tested', 'dm131:Level 2 #', 'dm131:Level 3+4 #', 'dm131:Number Tested'] 0.24444864851698977
# dm132
# ['buyer:Number Tested', 'dm132:SAT Math Avg. Score', 'dm132:Num of SAT Test Takers', 'dm132:SAT Critical Reading Avg. Score'] 0.011080860957920713
# dm133
# ['buyer:Number Tested', 'dm133:Total Parent \nResponse Rate', 'dm133:Total Teacher Response Rate', 'dm133:Total Student Response Rate'] 0.012586753817565688
# dm134
# ['dm134:2009-2010 PERFORMANCE CATEGORY SCORE', 'dm134:2009-2010 PROGRESS CATEGORY SCORE', 'dm134:DISTRICT', 'dm134:PEER INDEX*', 'dm134:2009-2010 ENVIRONMENT CATEGORY SCORE', 'buyer:Number Tested'] 0.23584175299057275
# dm135
# ['dm135:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm136
# ['dm136:BIN', 'dm136:Council District', 'dm136:Latitude', 'buyer:Number Tested', 'dm136:x', 'dm136:Census Tract'] 0.05528723016755477
# dm137
# ['buyer:Number Tested'] 0.00870173150757525
# dm138
# ['dm138:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm139
# ['dm139:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm140
# ['dm140:PERFORMANCE CATEGORY SCORE', 'dm140:ADDITIONAL CREDIT', 'dm140:PEER INDEX*', 'dm140:ENVIRONMENT CATEGORY SCORE', 'dm140:DISTRICT', 'buyer:Number Tested'] 0.2133772183346998
# dm141
# ['dm141:2014-15', 'buyer:Number Tested', 'dm141:District', 'dm141:2014-15 2', 'dm141:2014-15 3'] 0.02500082375084911
# dm142
# ['buyer:Number Tested', 'dm142:Student Communication Score', 'dm142:Teacher Engagement Score', 'dm142:Student Horizon Communication Score', 'dm142:Horizion Communication Score', 'dm142:Enrollment'] 0.008701731507719024
# dm143
# ['dm143:Level 3+4 %', 'dm143:Level 3 %', 'buyer:Number Tested', 'dm143:Year', 'dm143:Level 1 #', 'dm143:Number Tested'] 0.24130338192846879
# dm144
# ['buyer:Number Tested'] 0.00870173150757525
# dm145
# ['buyer:Number Tested'] 0.00870173150757525
# dm146
# ['dm146:Mean Scale Score', 'dm146:% Level 3+4', 'dm146:# Level 1', 'buyer:Number Tested', 'dm146:% Level 4', 'dm146:# Level 2'] 0.395334140999243
# dm147
# ['buyer:Number Tested', 'dm147:Closing the Achievement Gap Points'] 0.008701731507611221
# dm148
# ['buyer:Number Tested', 'dm148:app_gr09', 'dm148:seat_gr09'] 0.008806686604394987
# dm149
# ['buyer:Number Tested', 'dm149:Supportive Environment - Percent Positive', 'dm149:Enrollment', 'dm149:Rigorous Instruction - Percent Positive', 'dm149:Effective School Leadership - Percent Positive', 'dm149:Average Grade 8 English Proficiency'] 0.008701731507647192
# dm150
# ['dm150:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm151
# ['buyer:Number Tested', 'dm151:Community School District', 'dm151:City Council District'] 0.008757199466528642
# dm152
# ['dm152:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm153
# ['dm153:Total Parent \nResponse Rate', 'buyer:Number Tested'] 0.04573431361772429
# dm154
# ['dm154:2015-16', 'buyer:Number Tested', 'dm154:District', 'dm154:2015-16 1', 'dm154:2015-16 3'] 0.02914279551079313
# dm155
# ['buyer:Number Tested'] 0.00870173150757525
# dm156
# ['buyer:Number Tested', 'dm156:Percent Asian', 'dm156:Rigorous Instruction - Percent Positive', 'dm156:Percent English Language Learners', 'dm156:Percent Black', 'dm156:Student Attendance Rate'] 0.008830708502138851
# dm157
# ['dm157:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm158
# ['buyer:Number Tested', 'dm158:#Hispanic', 'dm158:#Female', 'dm158:Total Enrollment', 'dm158:#Male', 'dm158:#Grade 10'] 0.0088880839215838
# dm159
# ['buyer:Number Tested', 'dm159:Cohort Year', 'dm159:Total Cohort Num'] 0.008722668181220472
# dm160
# ['buyer:Number Tested', 'dm160:Total Cohort Num', 'dm160:Num achieving APM ', 'dm160:Total Grads Num'] 0.008757005693324382
# dm161
# ['dm161:# of teachers assigned to teach health', 'dm161:Community School District', 'dm161:City Council District', 'buyer:Number Tested'] 0.0388391331002228
# dm162
# ['dm162:Pct Level 4', 'dm162:Num Level 2', 'buyer:Number Tested', 'dm162:Pct Level 3', 'dm162:Mean Scale Score', 'dm162:Year'] 0.24491412396180645
# dm163
# ['buyer:Number Tested', 'dm163:9APP', 'dm163:9SEATS'] 0.008780303382410537
# dm164
# ['dm164:Average Class Size', 'buyer:Number Tested', 'dm164:Number of Classes', 'dm164:Number of Students'] 0.025877161496732803
# dm165
# ['dm165:white_per', 'dm165:asian_per', 'dm165:ell_percent', 'dm165:sped_percent', 'dm165:white_num', 'dm165:black_per'] 0.4868191193140424
# dm166
# ['buyer:Number Tested', 'dm166:AP Test Takers '] 0.008719451997312833
# dm167
# ['dm167:% Poverty', 'dm167:% Asian', 'dm167:% Special Class', 'dm167:% English Language Learners', 'dm167:% White', 'dm167:% Students with Disabilities'] 0.6019634051890174
# dm168
# ['dm168:Average Class Size', 'buyer:Number Tested', 'dm168:Maximum Class Size', 'dm168:Minimum Class Size', 'dm168:Number of Students', 'dm168:Number of Classes'] 0.02794124048709845
# dm169
# ['dm169:Total Enrollment', 'buyer:Number Tested', 'dm169:Grades Pk-5 Enrollment', 'dm169:District', 'dm169:Grades 9-12 Enrollment'] 0.024602277870178102
# dm170
# ['buyer:Number Tested', 'dm170:Effective School Leadership - Percent Positive', 'dm170:Percent Asian'] 0.008701731507647192
# dm171
# ['dm171:% Level 3+4', 'dm171:# Level 1', 'dm171:Mean Scale Score', 'buyer:Number Tested', 'dm171:% Level 4', 'dm171:Grade'] 0.4009714393525484
# dm172
# ['buyer:Number Tested', 'dm172:Total Enrolled Students'] 0.008746453165562662
# dm173
# ['dm173:Total Parent \nResponse Ratem %', 'buyer:Number Tested'] 0.018397218917423852
# dm174
# ['dm174:Level 4 %', 'dm174:Level 1 %', 'dm174:Grade', 'dm174:Year', 'dm174:Mean Scale Score', 'dm174:Level 4 #'] 0.4008744384393087
# dm175
# ['buyer:Number Tested'] 0.00870173150757525
# dm176
# ['buyer:Number Tested', 'dm176:Total Cohort #', 'dm176:Cohort Year'] 0.008733564381241954
# dm177
# ['buyer:Number Tested', 'dm177:Council District', 'dm177:Latitude', 'dm177:Census Tract', 'dm177:BBL', 'dm177:Community Board'] 0.00962248798274623
# dm178
# ['buyer:Number Tested', 'dm178:Total Cohort  - June'] 0.008708002493890032
# dm179
# ['dm179:Mean Scale Score', 'dm179:Level2_%', 'dm179:Level4_N', 'dm179:Level4_%', 'dm179:Level3+4_N', 'dm179:Level1_N'] 0.6347042166102745
# dm180
# ['buyer:Number Tested', 'dm180:# of 8th graders', 'dm180:Community School District', 'dm180:City Council District', 'dm180:# of students in grades 6-8'] 0.01353999283709817
# dm181
# ['buyer:Number Tested', 'dm181:p_q10a', 'dm181:N_t', 'dm181:p_q8b', 'dm181:p_q7', 'dm181:saf_s_10'] 0.008701731507683164
# dm182
# ['dm182:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested', 'dm182:SY1617 TOTAL REMOVALS/SUSPENSIONS'] 0.01809409651495142
# dm183
# ['dm183:Mean Scale Score', 'dm183:Level3+4_%', 'dm183:Grade', 'dm183:Level1_N', 'dm183:Level4_%', 'dm183:Level2_%'] 0.6092938259758833
# dm184
# ['buyer:Number Tested', 'dm184:Total Cohort Num', 'dm184:Total Regents Num', 'dm184:Dropped Out Num', 'dm184:Total Grads Num', 'dm184:Local Num'] 0.009035727291452078
# dm185
# ['buyer:Number Tested', 'dm185:MATH %Level 1', 'dm185:%Hispanic', 'dm185:%Black', 'dm185:Total Enrollment', 'dm185:#Female'] 0.01006989150823212
# dm186
# ['dm186:% Poverty', 'dm186:% Asian', 'dm186:% Students with Disabilities', 'dm186:% English Language Learners', 'dm186:% White', 'dm186:% Black'] 0.5740551105301209
# dm187
# ['dm187:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm188
# ['dm188:Mean Scale Score', 'dm188:Level 3+4: %', 'dm188:Level 4: #', 'dm188:Level 3: %', 'dm188:Level 3: #', 'dm188:Level 1: #'] 0.6500790757446933
# dm189
# ['buyer:Number Tested', 'dm189:Staff  completing training'] 0.008701776399745231
# dm190
# ['buyer:Number Tested'] 0.00870173150757525
# dm191
# ['dm191:Register', 'dm191:ID', 'dm191:# Schools', 'buyer:Number Tested'] 0.07256382802906947
# dm192
# ['buyer:Number Tested', 'dm192:Total Cohort #', 'dm192:Cohort Year'] 0.008706531955661956
# dm193
# ['buyer:Number Tested', 'dm193:# of students in grades 6-8', 'dm193:Community School District', 'dm193:City Council District', 'dm193:# of 8th graders'] 0.013816751207725408
# dm194
# ['dm194:Level 3+4 %', 'dm194:Level 2 %', 'dm194:Level 4 %', 'dm194:Level 1 #', 'buyer:Number Tested', 'dm194:Year'] 0.3338599191887198
# dm195
# ['dm195:Mean Scale Score', 'dm195:Level3+4_%', 'dm195:Level4_%', 'dm195:Level3_N', 'dm195:Grade', 'dm195:Number Tested'] 0.5732003445231633
# dm196
# ['buyer:Number Tested', 'dm196:# of 8th graders', 'dm196:Community School District', 'dm196:City Council District', 'dm196:# of students in grades 6-8'] 0.013386968593542825
# dm197
# ['buyer:Number Tested', 'dm197:Grade', 'dm197:Number Tested'] 0.02084363652697907
# dm198
# ['dm198:2011-2012 PERFORMANCE CATEGORY SCORE', 'dm198:2011-2012 ADDITIONAL CREDIT', 'dm198:PEER INDEX*', 'dm198:DISTRICT', 'dm198:2011-2012 ENVIRONMENT CATEGORY SCORE', 'dm198:2011-2012 PROGRESS CATEGORY SCORE'] 0.3431703355886152
# dm199
# ['buyer:Number Tested', 'dm199:8th Gr Math/ELA', 'dm199:% Free Lunch', 'dm199:Enrollment', 'dm199:% Students with Disabilites', 'dm199:Closing the Achievement Gap Points'] 0.011873804550329603
# dm200
# ['buyer:Number Tested', 'dm200:#Hispanic', 'dm200:#Female', 'dm200:Total Enrollment', 'dm200:#Male', 'dm200:#Black'] 0.008824748513496683
# dm201
# ['buyer:Number Tested', 'dm201:Economic Need Index', 'dm201:Strong Family-Community Ties - Percent Positive', 'dm201:Percent in Temp Housing', 'dm201:Average Grade 8 Math Proficiency', 'dm201:Enrollment'] 0.015488574089030926
# dm202
# ['buyer:Number Tested', 'dm202:total_students', 'dm202:number_programs', 'dm202:Census Tract', 'dm202:BIN', 'dm202:Council District'] 0.009302958723688026
# dm203
# ['buyer:Number Tested', 'dm203:Total Enrolled Students'] 0.008745905047627511
# dm204
# ['buyer:Number Tested', 'dm204:Percent in Temp Housing', 'dm204:Percent of teachers with 3 or more years of experience', 'dm204:Economic Need Index', 'dm204:Supportive Environment - Percent Positive', 'dm204:Rigorous Instruction - Percent Positive'] 0.008707711446152233
# dm205
# ['dm205:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm206
# ['buyer:Number Tested', 'dm206:Advanced Regents % of cohort', 'dm206:Advanced Regents #', 'dm206:Total Regents % of cohort', 'dm206:Total Regents % of grads', 'dm206:Advanced Regents % of grads'] 0.010049447896963493
# dm207
# ['dm207:Teacher Safety and Respect Score', 'dm207:Teacher Communication Score', 'dm207:Parent Communication Score', 'dm207:Parent Engagement Score', 'dm207:enrollment', 'dm207:Academic Expectations Score'] 0.29432261052459163
# dm208
# ['dm208:# of teachers assigned to teach health', 'dm208:Community School District', 'dm208:City Council District', 'buyer:Number Tested'] 0.0388391331002228
# dm209
# ['dm209:Level 3+4: %', 'dm209:Level 1: #', 'buyer:Number Tested', 'dm209:Level 3: %', 'dm209:Mean Scale Score', 'dm209:Grade'] 0.35319631253305916
# dm210
# ['dm210:Student Enrollment', 'dm210:Total Part Time and Full Time Licensed PE Teachers*', 'buyer:Number Tested', 'dm210:Admin District'] 0.09264472380092748
# dm211
# ['dm211:Present', 'dm211:Absent', 'dm211:GradeSort', 'dm211:Released', 'dm211:MonthCode', 'dm211:RosterCount'] 0.11374437712617147
# dm212
# ['dm212:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm213
# ['buyer:Number Tested', 'dm213:Rigorous Instruction - Percent Positive', 'dm213:Percent English Language Learners', 'dm213:Percent in Temp Housing'] 0.008701731507647192
# dm214
# ['dm214:Total Parent \nResponse Rate', 'buyer:Number Tested', 'dm214:Total Teacher Response Rate'] 0.03815648716144837
# dm215
# ['buyer:Number Tested'] 0.00870173150757525
# dm216
# ['dm216:Total Enrollment', 'buyer:Number Tested', 'dm216:District', 'dm216:Grades 6-8 Enrollment', 'dm216:Grades 9-12 Enrollment'] 0.024992346113753894
# dm217
# ['dm217:Pct Level 3 and 4', 'dm217:Pct Level 4', 'dm217:Num Level 2', 'buyer:Number Tested', 'dm217:Num Level 4', 'dm217:Mean Scale Score'] 0.24644944158766569
# dm218
# ['buyer:Number Tested'] 0.00870173150757525
# dm219
# ['buyer:Number Tested', 'dm219:CTE enrolled Student Count'] 0.008701735401338673
# dm220
# ['dm220:Average Class Size', 'dm220:Grade Level', 'dm220:Number of Students', 'dm220:Minimum Class Size', 'buyer:Number Tested', 'dm220:Number of Classes'] 0.06703750307833745
# dm221
# ['buyer:Number Tested'] 0.00870173150757525
# dm222
# ['buyer:Number Tested', 'dm222: Advanced Regents % of cohort', 'dm222: Advanced Regents #', 'dm222: Advanced Regents % of grads', 'dm222:Total Cohort #', 'dm222: Total Regents % of cohort'] 0.010635332878424886
# dm223
# ['dm223:Minimum Class Size', 'buyer:Number Tested', 'dm223:Average Class Size', 'dm223:Maximum Class Size', 'dm223:Number of Classes', 'dm223:Number of Students'] 0.025857151237716702
# dm224
# ['dm224:Level 4 %', 'dm224:Level 1 %', 'dm224:Grade', 'dm224:Level 2 %', 'dm224:Mean Scale Score', 'dm224:Year'] 0.37006478711100455
# dm225
# ['buyer:Number Tested', 'dm225:Grade'] 0.008701731507611221
# dm226
# ['buyer:Number Tested', 'dm226:Cohort Year', 'dm226:Total Cohort #'] 0.008712249458385446
# dm227
# ['dm227:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm228
# ['buyer:Number Tested'] 0.00870173150757525
# dm229
# ['dm229:Total Enrollment', 'buyer:Number Tested', 'dm229:District', 'dm229:Grades 6-8 Enrollment', 'dm229:Grades 9-12 Enrollment'] 0.024992346113753894
# dm230
# ['dm230:Pct Level 3 and 4', 'dm230:Pct Level 4', 'dm230:Num Level 2', 'buyer:Number Tested', 'dm230:Num Level 4', 'dm230:Mean Scale Score'] 0.24644944158766569
# dm231
# ['buyer:Number Tested'] 0.00870173150757525
# dm232
# ['buyer:Number Tested', 'dm232:CTE enrolled Student Count'] 0.008701735401338673
# dm233
# ['dm233:Average Class Size', 'dm233:Grade Level', 'dm233:Number of Students', 'dm233:Minimum Class Size', 'buyer:Number Tested', 'dm233:Number of Classes'] 0.06703750307833745
# dm234
# ['buyer:Number Tested'] 0.00870173150757525
# dm235
# ['buyer:Number Tested', 'dm235: Advanced Regents % of cohort', 'dm235: Advanced Regents #', 'dm235: Advanced Regents % of grads', 'dm235:Total Cohort #', 'dm235: Total Regents % of cohort'] 0.010635332878424886
# dm236
# ['dm236:Minimum Class Size', 'buyer:Number Tested', 'dm236:Average Class Size', 'dm236:Maximum Class Size', 'dm236:Number of Classes', 'dm236:Number of Students'] 0.025857151237716702
# dm237
# ['dm237:Level 4 %', 'dm237:Level 1 %', 'dm237:Grade', 'dm237:Level 2 %', 'dm237:Mean Scale Score', 'dm237:Year'] 0.37006478711100455
# dm238
# ['buyer:Number Tested', 'dm238:Grade'] 0.008701731507611221
# dm239
# ['buyer:Number Tested', 'dm239:Cohort Year', 'dm239:Total Cohort #'] 0.008712249458385446
# dm240
# ['dm240:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm241
# ['dm241:Community School District', 'dm241:City Council District', 'buyer:Number Tested'] 0.02805755364599405
# dm242
# ['buyer:Number Tested'] 0.00870173150757525
# dm243
# ['buyer:Number Tested', 'dm243:MATH %Level 1', 'dm243:%Hispanic', 'dm243:%Black', 'dm243:Total Enrollment', 'dm243:#Female'] 0.010069891508124318
# dm244
# ['dm244:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm245
# ['dm245:Level 3+4 %', 'dm245:Year', 'dm245:Level 3 %', 'dm245:Level 1 #', 'dm245:Number Tested', 'buyer:Number Tested'] 0.32341079988074406
# dm246
# ['buyer:Number Tested', 'dm246:Percent in Temp Housing', 'dm246:Effective School Leadership - Percent Positive', 'dm246:Supportive Environment - Percent Positive', 'dm246:Percent Overage/ Undercredit', 'dm246:Rigorous Instruction - Percent Positive'] 0.008706298478449837
# dm247
# ['buyer:Number Tested', 'dm247:Trust - Percent Positive', 'dm247:Percent English Language Learners', 'dm247:Enrollment', 'dm247:Percent HRA Eligible', 'dm247:Average Grade 8 Math Proficiency'] 0.008701731507683164
# dm248
# ['buyer:Number Tested', 'dm248:Total Cohort Num', 'dm248:Total Grads Num', 'dm248:Num achieving APM '] 0.008826807448744312
# dm249
# ['buyer:Number Tested', 'dm249:college_career_rate_2014', 'dm249:ontrack_year1_2014', 'dm249:pct_stu_enough_variety_2014', 'dm249:pct_stu_safe_2014', 'dm249:graduation_rate_2013'] 0.011332944456123872
# dm250
# ['dm250:Register', 'dm250:Latitude', 'dm250:Council District ', 'dm250:BIN', 'dm250:Longitude', 'dm250:# Schools'] 0.1989001651477592
# dm251
# ['dm251:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm252
# ['buyer:Number Tested', 'dm252:Grade', 'dm252:Number Tested'] 0.021811570384750567
# dm253
# ['dm253:School Pupil-Teacher Ratio', 'buyer:Number Tested'] 0.20977106004262602
# dm254
# ['dm254:Mean Scale Score', 'dm254:Number Tested', 'dm254:Level 1: #', 'dm254:Level 2: #', 'dm254:Level 3+4: #', 'dm254:Grade'] 0.3776955300897217
# dm255
# ['dm255:Total Safety and Respect Score', 'dm255:Total Engagement Score', 'buyer:Number Tested', 'dm255:Total Academic Expectations Score', 'dm255:Total Communication Score', 'dm255:Total Parent \nResponse Rate (%)'] 0.23371174045267817
# dm256
# ['buyer:Number Tested', 'dm256:attendance_rate', 'dm256:pct_stu_safe', 'dm256:Latitude', 'dm256:Council District', 'dm256:grade9swdapplicants1'] 0.011513478144655975
# dm257
# ['dm257:% Poverty', 'dm257:% Asian', 'dm257:% Students with Disabilities', 'dm257:% English Language Learners', 'dm257:% Black', 'dm257:% Hispanic'] 0.5717384262309178
# dm258
# ['buyer:Number Tested', 'dm258:Total Grads Num', 'dm258:Total Cohort Num'] 0.008766391343927982
# dm259
# ['dm259:Level 4 %', 'dm259:Level 1 #', 'buyer:Number Tested', 'dm259:Number Tested', 'dm259:Level 3+4 #', 'dm259:Level 3+4 %'] 0.2571017846730531
# dm260
# ['dm260:School Pupil-Teacher Ratio', 'buyer:Number Tested'] 0.25260799347444307
# dm261
# ['buyer:Number Tested'] 0.00870173150757525
# dm262
# ['dm262:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested', 'dm262:SY1617 TOTAL REMOVALS/SUSPENSIONS'] 0.01809409651495142
# dm263
# ['buyer:Number Tested', 'dm263:Geo. District ofBuilding(s)'] 0.010146498808294102
# dm264
# ['buyer:Number Tested', 'dm264:Total Enrolled Students'] 0.008941473734122796
# dm265
# ['dm265:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm266
# ['dm266:Pct Level 4', 'dm266:Pct Level 3 and 4', 'buyer:Number Tested', 'dm266:Num Level 2', 'dm266:Num Level 3 and 4', 'dm266:Number Tested'] 0.24816484553294627
# dm267
# ['dm267:Total Parent \nResponse Rate', 'buyer:Number Tested'] 0.025666417574606193
# dm268
# ['dm268:Pct Level 3 and 4', 'dm268:Pct Level 3', 'buyer:Number Tested', 'dm268:Year', 'dm268:Num Level 1', 'dm268:Number Tested'] 0.250472602140707
# dm269
# ['dm269:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm270
# ['dm270:% Poverty', 'dm270:% Asian', 'dm270:% Students with Disabilities', 'dm270:% English Language Learners', 'dm270:% Black', 'dm270:% Hispanic'] 0.6022201892222652
# dm271
# ['dm271:Level 4 %', 'dm271:Level 3 %', 'buyer:Number Tested', 'dm271:Level 1 #', 'dm271:Level 2 %', 'dm271:Level 3 #'] 0.20515271842453886
# dm272
# ['buyer:Number Tested', 'dm272:latitude', 'dm272:Council District', 'dm272:school_district', 'dm272:Census Tract', 'dm272:progcount'] 0.010383222307266626
# dm273
# ['buyer:Number Tested', 'dm273:Total Enrollment'] 0.01020855106951346
# dm274
# ['dm274:School Pupil-Teacher Ratio', 'buyer:Number Tested'] 0.21007728228589773
# dm275
# ['dm275:Element Percent Positive 4', 'buyer:Number Tested', 'dm275:Parent Percent Positive', 'dm275:Element Percent Positive 1', 'dm275:Total Parent \nResponse Rate', 'dm275:Total Teacher Response Rate'] 0.1637571501049846
# dm276
# ['buyer:Number Tested'] 0.00870173150757525
# dm277
# ['dm277:Count of Testers', 'dm277:Count of Students in HS Admissions', 'buyer:Number Tested'] 0.04551152951149129
# dm278
# ['buyer:Number Tested', 'dm278:Total Enrolled Students'] 0.00943912304548844
# dm279
# ['dm279:2010-2011 PERFORMANCE CATEGORY SCORE', 'dm279:DISTRICT', 'dm279:2010-2011 PROGRESS CATEGORY SCORE', 'dm279:PEER INDEX*', 'buyer:Number Tested', 'dm279:2010-2011 ENVIRONMENT CATEGORY SCORE'] 0.3090561817854097
# dm280
# ['buyer:Number Tested', 'dm280:graduation_rate', 'dm280:attendance_rate', 'dm280:grade9geapplicants1', 'dm280:grade9swdapplicants1', 'dm280:Census Tract'] 0.011962637629170714
# dm281
# ['dm281:Latitude', 'dm281:Council District', 'dm281:BIN', 'buyer:Number Tested', 'dm281:X Coordinate', 'dm281:Community Board'] 0.07905051120258655
# dm282
# ['buyer:Number Tested', 'dm282:Total Enrolled Students'] 0.00945877813139595
# dm283
# ['buyer:Number Tested', 'dm283:Total Engagement Score'] 0.008701731507611221
# dm284
# ['buyer:Number Tested', 'dm284: Advanced Regents % of cohort', 'dm284: Advanced Regents #', 'dm284: Advanced Regents % of grads', 'dm284:Total Cohort #', 'dm284:Dropped Out % of cohort'] 0.01086789436489477
# dm285
# ['dm285:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm286
# ['buyer:Number Tested', 'dm286:Total Enrolled Students'] 0.008761916069247033
# dm287
# ['dm287:Level 4 %', 'dm287:Level 2 #', 'buyer:Number Tested', 'dm287:Level 1 %', 'dm287:Year', 'dm287:Number Tested'] 0.23814006509729124
# dm288
# ['buyer:Number Tested', 'dm288:Cohort', 'dm288:Total Cohort'] 0.008741742867659164
# dm272
# ['buyer:Number Tested', 'dm272:latitude', 'dm272:Council District', 'dm272:school_district', 'dm272:Census Tract', 'dm272:progcount'] 0.010383222307266626
# dm273
# ['buyer:Number Tested', 'dm273:Total Enrollment'] 0.01020855106951346
# dm274
# ['dm274:School Pupil-Teacher Ratio', 'buyer:Number Tested'] 0.21007728228589773
# dm275
# ['dm275:Element Percent Positive 4', 'buyer:Number Tested', 'dm275:Parent Percent Positive', 'dm275:Element Percent Positive 1', 'dm275:Total Parent \nResponse Rate', 'dm275:Total Teacher Response Rate'] 0.1637571501049846
# dm276
# ['buyer:Number Tested'] 0.00870173150757525
# dm277
# ['dm277:Count of Testers', 'dm277:Count of Students in HS Admissions', 'buyer:Number Tested'] 0.04551152951149129
# dm278
# ['buyer:Number Tested', 'dm278:Total Enrolled Students'] 0.00943912304548844
# dm279
# ['dm279:2010-2011 PERFORMANCE CATEGORY SCORE', 'dm279:DISTRICT', 'dm279:2010-2011 PROGRESS CATEGORY SCORE', 'dm279:PEER INDEX*', 'buyer:Number Tested', 'dm279:2010-2011 ENVIRONMENT CATEGORY SCORE'] 0.3090561817854097
# dm280
# ['buyer:Number Tested', 'dm280:graduation_rate', 'dm280:attendance_rate', 'dm280:grade9geapplicants1', 'dm280:grade9swdapplicants1', 'dm280:Census Tract'] 0.011962637629170714
# dm281
# ['dm281:Latitude', 'dm281:Council District', 'dm281:BIN', 'buyer:Number Tested', 'dm281:X Coordinate', 'dm281:Community Board'] 0.07905051120258655
# dm282
# ['buyer:Number Tested', 'dm282:Total Enrolled Students'] 0.00945877813139595
# dm283
# ['buyer:Number Tested', 'dm283:Total Engagement Score'] 0.008701731507611221
# dm284
# ['buyer:Number Tested', 'dm284: Advanced Regents % of cohort', 'dm284: Advanced Regents #', 'dm284: Advanced Regents % of grads', 'dm284:Total Cohort #', 'dm284:Dropped Out % of cohort'] 0.01086789436489477
# dm285
# ['dm285:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm286
# ['buyer:Number Tested', 'dm286:Total Enrolled Students'] 0.008761916069247033
# dm287
# ['dm287:Level 4 %', 'dm287:Level 2 #', 'buyer:Number Tested', 'dm287:Level 1 %', 'dm287:Year', 'dm287:Number Tested'] 0.23814006509729124
# dm288
# ['buyer:Number Tested', 'dm288:Cohort', 'dm288:Total Cohort'] 0.008741742867659164
# dm289
# ['dm289:Absent', 'dm289:Present', 'dm289:grade sort', 'dm289:MonthCode', 'buyer:Number Tested', 'dm289:Release'] 0.08101025286623387
# dm290
# ['dm290:ADDITIONAL CREDIT', 'dm290:OVERALL SCORE', 'dm290:PEER INDEX*', 'dm290:DISTRICT', 'buyer:Number Tested', 'dm290:ENVIRONMENT CATEGORY SCORE'] 0.16937927987489554
# dm291
# ['buyer:Number Tested', 'dm291:Total Enrollment (Half Day & Full Day)', 'dm291:#Female', 'dm291:#Male'] 0.01032114899883374
# dm292
# ['dm292:Count of Testers', 'dm292:Count of Students in HS Admissions', 'buyer:Number Tested'] 0.048452728551246826
# dm293
# ['buyer:Number Tested', 'dm293:Overall Rank', 'dm293:Average Math Proficiency', 'dm293:% ELL', 'dm293:Average English Proficiency', 'dm293:% Self-Contained'] 0.008701731507683164
# dm294
# ['buyer:Number Tested', 'dm294:graduation_rate', 'dm294:grade9swdapplicants1', 'dm294:grade9geapplicants1', 'dm294:attendance_rate', 'dm294:Council District'] 0.011607234158978796
# dm295
# ['dm295:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested', 'dm295:SY1617 TOTAL REMOVALS/SUSPENSIONS'] 0.01809409651495142
# dm296
# ['dm296:Total SW & GC', 'buyer:Number Tested'] 0.027144681087872824
# dm297
# ['buyer:Number Tested'] 0.00870173150757525
# dm298
# ['dm298:Total Parent \nResponse Rate', 'buyer:Number Tested', 'dm298:Total Teacher Response Rate'] 0.03815648716144837
# dm299
# ['dm299:PERFORMANCE CATEGORY SCORE', 'dm299:ADDITIONAL CREDIT', 'dm299: PEER INDEX* ', 'dm299:ENVIRONMENT CATEGORY SCORE', 'dm299:DISTRICT', 'buyer:Number Tested'] 0.21337648815252808
# dm300
# ['dm300:Ratio GC & SW', 'dm300:Full Time', 'dm300:Total SW & GC', 'dm300:SY2014-15 Enrollment', 'dm300:Ratio GC Only', 'dm300:Total GC'] 0.16073138586456304
# dm301
# ['buyer:Number Tested', 'dm301:Staff  completing training'] 0.00870181350492738
# dm302
# ['dm302:Pct Level 3 and 4', 'dm302:Pct Level 3', 'dm302:Year', 'dm302:Grade', 'dm302:Mean Scale Score', 'dm302:Num Level 4'] 0.44780183404410134
# dm303
# ['dm303:Ratio GC & SW', 'dm303:Full Time', 'dm303:Total SW & GC', 'dm303:SY2014-15 Enrollment', 'dm303:Ratio GC Only', 'dm303:Total GC'] 0.16073138586456304
# dm304
# ['dm304:School Pupil-Teacher Ratio', 'buyer:Number Tested'] 0.21007728228589773
# dm305
# ['dm305:Mean Scale Score', 'dm305:Level3+4_%', 'dm305:Grade', 'dm305:Level4_%', 'dm305:Level2_%', 'dm305:Level1_N'] 0.5861202657970901
# dm306
# ['dm306:Student Enrollment', 'dm306:Total Part Time and Full Time Licensed PE Teachers - As of 10/31/2015 (APE teachers not included) - Elementary, Early Childhood, and K-8 teachers providing physical education under a common branch license are not included', 'buyer:Number Tested', 'dm306:Admin District'] 0.09264472380092748
# dm307
# ['buyer:Number Tested', 'dm307:student_satisfaction_historic_avg_similar_schls', 'dm307:student_satisfaction_2012', 'dm307:student_satisfaction_2013'] 0.010595522576567484
# dm308
# ['dm308:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm309
# ['dm309:Total Safety and Respect Score', 'dm309:Total Communication Score', 'dm309:Total Academic Expectations Score', 'buyer:Number Tested', 'dm309:Total Engagement Score'] 0.2468879543933753
# dm310
# ['dm310:Total Safety and Respect Score', 'dm310:Total Communication Score', 'dm310:Total Academic Expectations Score', 'buyer:Number Tested', 'dm310:Total Engagement Score'] 0.2468879543933753
# dm311
# ['dm311:2011-2012 PERFORMANCE CATEGORY SCORE', 'dm311:2011-2012 ADDITIONAL CREDIT', 'dm311:PEER INDEX*', 'dm311:DISTRICT', 'dm311:2011-2012 ENVIRONMENT CATEGORY SCORE', 'dm311:2011-2012 PROGRESS CATEGORY SCORE'] 0.3431703355886152
# dm312
# ['dm312:% Poverty', 'dm312:% Asian', 'buyer:Number Tested', 'dm312:District', 'dm312:Grades 6-8 Enrollment', 'dm312:% ELL'] 0.14853446369880308
# dm313
# ['dm313:Count of Students in HS Admissions', 'buyer:Number Tested'] 0.03184031379904184
# dm314
# ['dm314:% Poverty', 'dm314:% Asian', 'dm314:% Students with Disabilities', 'dm314:% English Language Learners', 'dm314:% Black', 'dm314:% Hispanic'] 0.6063491316654033
# dm315
# ['buyer:Number Tested', 'dm315:Cohort Year'] 0.00872345339817493
# dm316
# ['dm316:Level 3 or Higher (%)', 'buyer:Number Tested', 'dm316:Number Tested', 'dm316:Level 3 or Higher (#)'] 0.15585965359548903
# dm317
# ['buyer:Number Tested', 'dm317:Grade', 'dm317:Number Tested'] 0.01746040458465503
# dm318
# ['dm318:Pct Level 4', 'dm318:Num Level 1', 'buyer:Number Tested', 'dm318:Pct Level 2', 'dm318:Number Tested', 'dm318:Num Level 3 and 4'] 0.26282120951946997
# dm319
# ['dm319:District', 'buyer:Number Tested'] 0.0206006148234128
# dm320
# ['dm320:PERFORMANCE CATEGORY SCORE', 'dm320:PEER INDEX*', 'dm320:ADDITIONAL CREDIT', 'dm320:DISTRICT', 'dm320:ENVIRONMENT CATEGORY SCORE', 'buyer:Number Tested'] 0.17140060663725498
# dm321
# ['dm321:Level3+4_%', 'dm321:Level1_N', 'buyer:Number Tested', 'dm321:Mean Scale Score', 'dm321:Level3_%', 'dm321:Grade'] 0.30063932419431205
# dm322
# ['buyer:Number Tested'] 0.00870173150757525
# dm323
# ['dm323:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm324
# ['buyer:Number Tested', 'dm324:Enrolled Student Counts', 'dm324:Number of Industry Partners'] 0.008703090307405348
# dm325
# ['buyer:Number Tested', 'dm325:Economic Need Index', 'dm325:Percent HRA Eligible', 'dm325:Rigorous Instruction - Percent Positive', 'dm325:Percent Asian', 'dm325:Enrollment'] 0.008847830009802826
# dm326
# ['dm326:2010-2011 PERFORMANCE CATEGORY SCORE', 'dm326:2010-2011 OVERALL SCORE', 'dm326:DISTRICT', 'dm326:PEER INDEX*', 'buyer:Number Tested', 'dm326:2010-2011 ENVIRONMENT CATEGORY SCORE'] 0.35576037396518145
# dm327
# ['buyer:Number Tested', 'dm327:Grade', 'dm327:Number Tested'] 0.016026359478341634
# dm328
# ['dm328:ADMINISTRATIVE DISTRICT', 'buyer:Number Tested'] 0.0200527935933692
# dm329
# ['dm329:Level 3+4 %', 'dm329:Level 3 %', 'dm329:Mean Scale Score', 'dm329:Level 4 #', 'dm329:Grade', 'dm329:Level 2 #'] 0.4357000026310125
# dm330
# ['dm330:Pct Level 3 and 4', 'dm330:Pct Level 4', 'dm330:Year', 'dm330:Grade', 'dm330:Mean Scale Score', 'dm330:Num Level 4'] 0.4037111271339824
# dm331
# ['buyer:Number Tested', 'dm331:Total Student Response Rate', 'dm331:Total Safety and Respect Score', 'dm331:Total Teacher Response Rate', 'dm331:Total Parent Response Rate'] 0.008701731507611221
# dm332
# ['dm332:Level 3+4 %', 'dm332:Level 4 %', 'dm332:Level 2 #', 'buyer:Number Tested', 'dm332:Level 4 #', 'dm332:Number Tested'] 0.24267194964893624
# dm333
# ['buyer:Number Tested', 'dm333:Writing Mean', 'dm333:Number of Test Takers', 'dm333:Mathematics Mean', 'dm333:Critical Reading Mean'] 0.010881058613883776
# dm59 ['dm59:Average Grade 4 English Proficiency', 'dm59:Economic Need Index', 'dm59:Average Grade 4 Math Proficiency', 'dm59:% ELL', 'dm59:% Self-Contained', 'buyer:Number Tested'] 0.6643513790215417

# %%
# make best_dimension a list
if isinstance(best_dimension, tuple):
    best_dimension = list(best_dimension)
else:
    best_dimension = [best_dimension]

# extract needed attributes
seller_features = ['cov:s:' +  attr for attr in best_seller_attrs  if attr.startswith(best_seller.name)]
buyer_features = ['cov:s:' +  attr for attr in best_seller_attrs  if not attr.startswith(best_seller.name)]
target = ['cov:s:buyer:' + y]
buyer_train_data_df = buyer_train_data.data[buyer_train_data.dedup_dimensions + buyer_features + target]
buyer_test_data_df = buyer_test_data.data[buyer_train_data.dedup_dimensions + buyer_features + target]
seller_data = best_seller.data[best_dimension + seller_features]
# seller_data = seller_data.groupby(best_dimension).mean()

# join buyer and seller
join_train = pd.merge(buyer_train_data_df,seller_data,how='left', on=best_dimension)
join_test = pd.merge(buyer_test_data_df,seller_data,how='left', on=best_dimension)

for cate in categories:
    join_train = join_train.astype({cate: 'category'})
    join_test = join_test.astype({cate: 'category'})

# %%
timeleft = time_budget - (end - start)

# %%
# %%time
# model performance with autoML 
X_train = join_train[categories + seller_features + buyer_features]
y_train = join_train[target]
X_test = join_test[categories + seller_features + buyer_features]
y_test = join_test[target]

automl = autosklearn.regression.AutoSklearnRegressor(
# automl = autosklearn.classification.AutoSklearnClassifier(
    time_left_for_this_task=int(timeleft),
    per_run_time_limit=int(timeleft/3),
    memory_limit=23072
#     ,metric=autosklearn.metrics.r2
)

automl.fit(X_train, y_train, X_test, y_test, dataset_name='buyer')
# Out:
# CPU times: user 1.09 s, sys: 1.57 s, total: 2.66 s
# Wall time: 4min 9s
# AutoSklearnRegressor(memory_limit=23072, per_run_time_limit=83,
#                      time_left_for_this_task=249)

# %%
train_predictions = automl.predict(X_train)
print("Train R2 score:", sklearn.metrics.r2_score(y_train, train_predictions))
test_predictions = automl.predict(X_test)
print("Test R2 score:", sklearn.metrics.r2_score(y_test, test_predictions))
print(automl.leaderboard())
poT = automl.performance_over_time_
print(poT)
poT.plot(
    x='Timestamp',
    kind='line',
    legend=True,
    title='Auto-sklearn accuracy over time',
    grid=True,
)
# Out:
# Train R2 score: 0.9290096152480338
# Test R2 score: 0.8356692896092124
#           rank  ensemble_weight           type      cost  duration
# model_id
# 2            1              1.0  random_forest  0.168266  71.84827
#                    Timestamp  ensemble_optimization_score  \
# 1 2022-04-16 00:10:08.000000                          NaN
# 0 2022-04-16 00:10:08.232887                     0.831734
#
#    ensemble_test_score  single_best_optimization_score  \
# 1                  NaN                        0.831734
# 0             0.835669                        0.831734
#
#    single_best_train_score  single_best_test_score
# 1                 0.976062                0.835669
# 0                 0.976062                0.835669
# <AxesSubplot:title={'center':'Auto-sklearn accuracy over time'}, xlabel='Timestamp'>
